# %%
#!python 3.10
#@author Y Ying

#dependencies
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

#.py files
import frequency_fft as freq

#plot and styles
import seaborn as sns
sns.set_style("ticks")
sns.set_context("talk")
sns.set_palette(sns.color_palette())

# %%
# generate sample model and perform FFT to get frequency
timeStep = 1e-3
numStep = 500
fluctuations, timeScale = freq.generate_sample_model(timeStep = timeStep, numStep = numStep)
freq.plot_fluctuations(fluctuations, timeScale, timeStep = timeStep, numStep = numStep, cutoff = 150)
# Out:
# True
